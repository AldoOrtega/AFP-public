# %% [markdown]
# # 2. Visualizando productos
#
# Los productos (cuentas) asociados a cada usuario se encuentran en 4 tablas : CCO, CCV, CDC y CAV (una tabla para cada cuenta). La cuenta CCO es la cuenta obligatoria, es decir, se concidera a una persona cliente solo si tiene contratada esta cuenta. Un cliente puede contratar las 4 cuentas a la vez.

# %%
import pandas as pd
 
cuenta = 'CCO'    
file = '../AFP data/Productos/productos'+cuenta+'.csv'
print("cargando cuenta "+cuenta)
cco = pd.read_csv(file, decimal = ',')

cuenta = 'CCV'    
file = '../AFP data/Productos/productos'+cuenta+'.csv'
print("cargando cuenta "+cuenta)
ccv = pd.read_csv(file, decimal = ',')

cuenta = 'CDC'    
file = '../AFP data/Productos/productos'+cuenta+'.csv'
print("cargando cuenta "+cuenta)
cdc = pd.read_csv(file, decimal = ',')

cuenta = 'CAV'    
file = '../AFP data/Productos/productos'+cuenta+'.csv'
print("cargando cuenta "+cuenta)
cav = pd.read_csv(file, decimal = ',')
# Out:
# cargando cuenta CCO
# /home/aldo/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# cargando cuenta CCV
# cargando cuenta CDC
# cargando cuenta CAV

# %%
cols_to_hide = ['ID_NUM_CLIENTE','RUT','RUTDV']

# %%
cco.drop(columns=cols_to_hide).head()
# Out:
#   PRODUCTO TIPO FECHA_CONTRATACION FECHA_TRASPASO  VIGENTE REGIMEN_TRIBUTARIO  \
# 0      CCO    O         01-09-1997            NaN  Vigente                  N
# 1      CCO    O         01-03-2001            NaN  Vigente                  N
# 2      CCO    O         01-08-1994            NaN  Vigente                  N
# 3      CCO    O         01-01-1997            NaN  Vigente                  N
# 4      CCO    O         15-10-1981            NaN  Vigente                  N
#
#    FONDO_A  FONDO_B  FONDO_C  FONDO_D  FONDO_E  FLUJO  MONTO  MONEDA  \
# 0      NaN      NaN      NaN      NaN      0.0    NaN    NaN     NaN
# 1      NaN      NaN      NaN  5689.77      NaN    NaN    NaN     NaN
# 2      NaN      NaN      NaN     0.00      NaN    NaN    NaN     NaN
# 3      NaN      NaN  1128.68      NaN      NaN    NaN    NaN     NaN
# 4      NaN      NaN      NaN     0.16      NaN    NaN    NaN     NaN
#
#    ULTIMO_FLUJO
# 0           NaN
# 1           NaN
# 2           NaN
# ...

# %% [markdown]
# Vamos a revisar si todas las cuentas tienen los mismos atributos

# %%
print ("cco - ccv")
print(list(cco) == list(ccv))

print ("cco - ccv")
print(list(cco) == list(cdc))

print ("cco - ccv")
print(list(cco) == list(cav))
# Out:
# cco - ccv
# False
# cco - ccv
# True
# cco - ccv
# True

# %% [markdown]
# Pareciera haber un problema...

# %%
# Listando atributos de cada producto

print ("cco")
print (list(cco))

print ("ccv")
print (list(ccv))

print ("cdc")
print (list(cdc))

print ("cav")
print (list(cav))
# Out:
# cco
# ['ID_NUM_CLIENTE', 'RUT', 'RUTDV', 'PRODUCTO', 'TIPO', 'FECHA_CONTRATACION', 'FECHA_TRASPASO', 'VIGENTE', 'REGIMEN_TRIBUTARIO', 'FONDO_A', 'FONDO_B', 'FONDO_C', 'FONDO_D', 'FONDO_E', 'FLUJO', 'MONTO', 'MONEDA', 'ULTIMO_FLUJO']
# ccv
# ['RUTDV', 'PRODUCTO', 'TIPO', 'FECHA_CONTRATACION', 'FECHA_TRASPASO', 'VIGENTE', 'REGIMEN_TRIBUTARIO', 'FONDO_A', 'FONDO_B', 'FONDO_C', 'FONDO_D', 'FONDO_E', 'FLUJO', 'MONTO', 'MONEDA', 'ULTIMO_FLUJO']
# cdc
# ['ID_NUM_CLIENTE', 'RUT', 'RUTDV', 'PRODUCTO', 'TIPO', 'FECHA_CONTRATACION', 'FECHA_TRASPASO', 'VIGENTE', 'REGIMEN_TRIBUTARIO', 'FONDO_A', 'FONDO_B', 'FONDO_C', 'FONDO_D', 'FONDO_E', 'FLUJO', 'MONTO', 'MONEDA', 'ULTIMO_FLUJO']
# cav
# ['ID_NUM_CLIENTE', 'RUT', 'RUTDV', 'PRODUCTO', 'TIPO', 'FECHA_CONTRATACION', 'FECHA_TRASPASO', 'VIGENTE', 'REGIMEN_TRIBUTARIO', 'FONDO_A', 'FONDO_B', 'FONDO_C', 'FONDO_D', 'FONDO_E', 'FLUJO', 'MONTO', 'MONEDA', 'ULTIMO_FLUJO']

# %% [markdown]
# A CCV le faltan las columnas 'ID_NUM_CLIENTE' y 'RUT'

# %% [markdown]
# ### Cuentas describe()

# %%
cco.describe()
# Out:
#        ID_NUM_CLIENTE           RUT        FONDO_A        FONDO_B  \
# count    7.525550e+05  7.525550e+05  168675.000000  137657.000000
# mean     8.620078e+05  1.099010e+07     630.003601     673.751147
# std      5.196637e+05  4.107644e+06     541.785446     894.197745
# min      9.000000e+00  2.375000e+03       0.000000       0.000000
# 25%      3.850360e+05  7.827382e+06     247.180000     111.190000
# 50%      8.731100e+05  1.078716e+07     492.670000     350.370000
# 75%      1.350326e+06  1.379336e+07     837.215000     869.810000
# max      1.651522e+06  5.300111e+07    8642.710000   12983.020000
#
#              FONDO_C        FONDO_D        FONDO_E  FLUJO  MONTO  MONEDA  \
# count  268484.000000  153373.000000  113547.000000    0.0    0.0     0.0
# mean      694.214964     615.692757     874.369631    NaN    NaN     NaN
# std       869.228268    1134.889532    1052.437849    NaN    NaN     NaN
# min         0.000000       0.000000       0.000000    NaN    NaN     NaN
# ...

# %%
cco.describe()
# Out:
#        ID_NUM_CLIENTE           RUT        FONDO_A        FONDO_B  \
# count    7.525550e+05  7.525550e+05  168675.000000  137657.000000
# mean     8.620078e+05  1.099010e+07     630.003601     673.751147
# std      5.196637e+05  4.107644e+06     541.785446     894.197745
# min      9.000000e+00  2.375000e+03       0.000000       0.000000
# 25%      3.850360e+05  7.827382e+06     247.180000     111.190000
# 50%      8.731100e+05  1.078716e+07     492.670000     350.370000
# 75%      1.350326e+06  1.379336e+07     837.215000     869.810000
# max      1.651522e+06  5.300111e+07    8642.710000   12983.020000
#
#              FONDO_C        FONDO_D        FONDO_E  FLUJO  MONTO  MONEDA  \
# count  268484.000000  153373.000000  113547.000000    0.0    0.0     0.0
# mean      694.214964     615.692757     874.369631    NaN    NaN     NaN
# std       869.228268    1134.889532    1052.437849    NaN    NaN     NaN
# min         0.000000       0.000000       0.000000    NaN    NaN     NaN
# ...

# %%
ccv.describe()
# Out:
#             FONDO_A       FONDO_B       FONDO_C       FONDO_D       FONDO_E  \
# count  85630.000000  29554.000000  66734.000000  20965.000000  52062.000000
# mean      58.235758     73.879277     76.231016     97.604265     57.325001
# std      330.582307    418.898948    429.602522    625.214956    331.568157
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.390000      0.420000      0.470000      0.360000      0.250000
# 75%        9.237500      9.920000      9.350000      7.490000      7.757500
# max    14459.670000  18636.890000  18016.060000  28073.120000  12512.140000
#
#               MONTO
# count  7.600400e+04
# mean   1.902078e+05
# std    1.035036e+07
# min    0.000000e+00
# 25%    2.631821e+04
# 50%    5.000000e+04
# 75%    1.000000e+05
# max    2.444000e+09

# %%
cdc.describe()
# Out:
#        ID_NUM_CLIENTE           RUT       FONDO_A       FONDO_B       FONDO_C  \
# count    4.308300e+04  4.308300e+04  14987.000000   5137.000000  12299.000000
# mean     8.671999e+05  1.069184e+07    206.179295    263.156225    324.594464
# std      5.036456e+05  3.635904e+06    956.154362   1223.229201   1621.345198
# min      1.360000e+02  5.582300e+04      0.000000      0.000000      0.000000
# 25%      3.984390e+05  7.813508e+06      1.205000      0.280000      0.180000
# 50%      8.660540e+05  1.040464e+07     20.960000     16.920000     15.800000
# 75%      1.349848e+06  1.325643e+07     98.295000    100.770000    104.010000
# max      1.651570e+06  9.681352e+07  43618.320000  37447.470000  70331.050000
#
#              FONDO_D       FONDO_E  FLUJO  MONTO  MONEDA  ULTIMO_FLUJO
# count    4184.000000  10122.000000    0.0    0.0     0.0           0.0
# mean      336.765896    197.991407    NaN    NaN     NaN           NaN
# ...

# %%
cav.describe()
# Out:
#        ID_NUM_CLIENTE           RUT       FONDO_A       FONDO_B  \
# count    2.945060e+05  2.945060e+05  65187.000000  33862.000000
# mean     7.248764e+05  9.790099e+06     36.894675     25.025780
# std      4.988304e+05  3.354209e+06    382.054332    233.909319
# min      1.400000e+01  2.258500e+04      0.000000      0.000000
# 25%      2.855935e+05  7.162688e+06      0.000000      0.000000
# 50%      6.289385e+05  9.527368e+06      0.040000      0.020000
# 75%      1.215460e+06  1.223414e+07      1.720000      0.970000
# max      1.651568e+06  7.889651e+07  39343.480000  12545.550000
#
#              FONDO_C       FONDO_D       FONDO_E  FLUJO  MONTO  MONEDA  \
# count  105869.000000  66072.000000  52351.000000    0.0    0.0     0.0
# mean       32.809161     21.558501     34.356546    NaN    NaN     NaN
# std       370.809786    304.146258    353.551737    NaN    NaN     NaN
# min         0.000000      0.000000      0.000000    NaN    NaN     NaN
# ...

# %% [markdown]
# Todos los valores son positivos, por tal a priori no se detectan inconsistencias en los rangos

# %% [markdown]
# ## Matrix
#
# The msno.matrix nullity matrix is a data-dense display which lets you quickly visually pick out patterns in data completion.

# %%
cuentas = pd.DataFrame()
cuentas = cuentas.append(cco)
cuentas = cuentas.append(cdc)
cuentas = cuentas.append(cav)

# %%
import numpy as np

cuentas = cuentas.replace("nan", np.nan)

import missingno as msno
# %matplotlib inline

msno.matrix(cuentas.sample(50))

# %%
msno.bar(cuentas)

# %%
ccv = ccv.replace("nan", np.nan)

import missingno as msno
# %matplotlib inline

msno.matrix(ccv.sample(50))

# %%
msno.bar(ccv)

# %% [markdown]
# ## Dendrogram
#
# The dendrogram allows you to more fully correlate variable completion, revealing trends deeper than the pairwise ones visible in the correlation heatmap.
#
# The dendrogram uses a hierarchical clustering algorithm (courtesy of scipy) to bin variables against one another by their nullity correlation (measured in terms of binary distance). At each step of the tree the variables are split up based on which combination minimizes the distance of the remaining clusters. The more monotone the set of variables, the closer their total distance is to zero, and the closer their average distance (the y-axis) is to zero.

# %%
msno.dendrogram(cuentas)
